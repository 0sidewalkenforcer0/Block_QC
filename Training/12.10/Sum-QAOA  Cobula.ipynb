# %%
import sys
import time
import numpy as np
import pandas as pd
import pennylane as qml
import seaborn as sns
from dwave_qbsolv import QBSolv
from matplotlib import pyplot as plt
from pennylane import qaoa
import copy
import progressbar
import os
import os.path
from qiskit import IBMQ

import dimod.utilities

# %% [markdown]
# ![image.png](attachment:5970fff2-e4c6-4e42-af99-86c48afc041a.png)

# %%
#complex
'''
number_set = [5, 3, 1, 4, 10]
S = 15
'''
# Out:
# '\nnumber_set = [5, 3, 1, 4, 10]\nS = 15\n'

# %%
#easy
number_set = [2,1,4]
S = 5

# %%
def fill_QUBO(number_set, S):
    n = len(number_set)
    QUBO = np.zeros((n, n))
    
    #Lin Terms
    for i in range(n):
        w_i = number_set[i]
        QUBO[i][i] = w_i*w_i-2*S*w_i
        #print(w_i*w_i-2*S*w_i)
        
        #Quadratische Terms
        for j in range(i+1, n, 1):
            w_j = number_set[j]
            QUBO[i][j] = 2*w_i*w_j
    return QUBO

# %%
QUBO = fill_QUBO(number_set, S)

# %%
QUBO
# Out:
# array([[-16.,   4.,  16.],
#        [  0.,  -9.,   8.],
#        [  0.,   0., -24.]])

# %%
n = len(number_set)

qubo_d = {}
x1 = 0
while x1 < n:
    x2 = x1
    while x2 < n:
        qubo_d[(x1, x2)] = int(QUBO[x1][x2])
        x2 += 1
    x1 += 1
    
print(qubo_d)
# Out:
# {(0, 0): -16, (0, 1): 4, (0, 2): 16, (1, 1): -9, (1, 2): 8, (2, 2): -24}

# %%
isingX = dimod.qubo_to_ising(qubo_d, 0)
print(isingX)
(linear, quadratic, _) = isingX
print("\n")
print(linear)
print("\n")
print(quadratic)
# Out:
# ({0: -3.0, 1: -1.5, 2: -6.0}, {(0, 1): 1.0, (0, 2): 4.0, (1, 2): 2.0}, -17.5)
#
#
# {0: -3.0, 1: -1.5, 2: -6.0}
#
#
# {(0, 1): 1.0, (0, 2): 4.0, (1, 2): 2.0}

# %%
n_qubits = n
wires = range(n_qubits)
depthX = 1

# %%
linear_coefficents = [linear[i] for i in range(n_qubits) if i in linear]
linear_gates = [qml.PauliZ(i) for i in range(n_qubits) if i in linear]
quadratic_coefficents = [quadratic[(i, j)] for i in range(n_qubits) for j in range(n_qubits) if (i, j) in quadratic]
quadratic_gates = [qml.PauliZ(i) @ qml.PauliZ(j) for i in range(n_qubits) for j in range(n_qubits) if
                       (i, j) in quadratic]

coefficents = linear_coefficents + quadratic_coefficents
gates = linear_gates + quadratic_gates

cost_h = qml.Hamiltonian(coefficents, gates)

# %%
print(cost_h)
# Out:
#   (-6.0) [Z2]
# + (-3.0) [Z0]
# + (-1.5) [Z1]
# + (1.0) [Z0 Z1]
# + (2.0) [Z1 Z2]
# + (4.0) [Z0 Z2]

# %%
mixer_h = qaoa.x_mixer(0)
for i in range(n_qubits - 1):
    mixer_h += qaoa.x_mixer(i + 1)

# %%
print(mixer_h)
# Out:
#   (1) [X0]
# + (1) [X1]
# + (1) [X2]

# %%
def qaoa_layer(gamma, alpha):
    qaoa.cost_layer(gamma, cost_h)
    qaoa.mixer_layer(alpha, mixer_h)

# %%
def circuit(params, **kwargs):
    for w in wires:
        qml.Hadamard(wires=w)
    qml.layer(qaoa_layer, depthX, params[0], params[1])

# %%
token = '1c854f9916477c15b8ef30c1243313b67e739cfc30f10cd741d7ad787f102bca0f0e60f474acc939c10761884cc75eff19910dbc5fb2e045c1f56dc1b274d553'

# %%
depthX = 2

# %%
dev = qml.device("qiskit.ibmq", wires=wires, ibmqx_token=token)
# Out:
# ---------------------------------------------------------------------------
# IBMQAccountError                          Traceback (most recent call last)
# <ipython-input-42-4651caa044df> in <module>
# ----> 1 dev = qml.device("qiskit.ibmq", wires=wires, ibmqx_token=token)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\__init__.py in device(name, *args, **kwargs)
#     263
#     264         # load device
# --> 265         return plugin_device_class(*args, **options)
#     266
#     267     raise DeviceError("Device does not exist. Make sure the required plugin is installed.")
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane_qiskit\ibmq.py in __init__(self, wires, provider, backend, shots, **kwargs)
#      71             # IBM Q account manually
#      72             ibmq_kwargs = {"url": url} if url is not None else {}
# ---> 73             IBMQ.enable_account(token, **ibmq_kwargs)
#      74         else:
#      75             # check if an IBM Q account is already active.
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py in enable_account(self, token, url, hub, group, project, **kwargs)
#      91         # Check if an IBM Quantum Experience account is already in use.
#      92         if self._credentials:
# ---> 93             raise IBMQAccountError(
#      94                 'An IBM Quantum Experience account is already in use for the session.')
#      95
#
# IBMQAccountError: 'An IBM Quantum Experience account is already in use for the session.'

# %%
cost_function = qml.ExpvalCost(circuit, cost_h, dev, optimize=True)

# %%
from scipy.optimize import minimize


expectation = get_expectation(G, p=1)

res = minimize(expectation, 
                      [1.0, 1.0], 
                      method='COBYLA')
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-d4fb0bddba92> in <module>
#       2
#       3
# ----> 4 expectation = get_expectation(G, p=1)
#       5
#       6 res = minimize(expectation,
#
# NameError: name 'get_expectation' is not defined

# %%
optimizer = qml.AdamOptimizer() # qml.GradientDescentOptimizer() # qml.AdamOptimizer() # qml.AdagradOptimizer()

# %%
params = [[1.5, 1,0],[1.5, 1.0]] #pre-optimized parameters

print("Start parameters: ", params)
# Out:
# Start parameters:  [[1.5, 1, 0], [1.5, 1.0]]

# %%
steps = 5

optimizerType = type(optimizer).__name__
path = os.getcwd()
print(path)
savestring = path + f"\{optimizerType}_{depthX}_{steps}_{params}"
print(savestring)
# Out:
# C:\Users\potap\PycharmProjects\quantum-walks-away\QW\QC Praktitum Kranzlmüller\12.10
# C:\Users\potap\PycharmProjects\quantum-walks-away\QW\QC Praktitum Kranzlmüller\12.10\AdamOptimizer_1_5_[[1.5, 1, 0], [1.5, 1.0]]

# %%
for i in progressbar.progressbar(range(steps), redirect_stdout=True):
    params = optimizer.step(cost_function, params)
    print(' | New parameters:', params)
    print("\n", dev.num_executions)
    f = open(savestring + "paramsQuicksaveIBM.txt", 'a+')
    f.write("parameter quicksave stepnumber " + str(i) + ": " + str(params) + "\n\n")
    f.close()

print("\n")
print("Optimal parameters: ", params)
# Out:
# N/A% (0 of 5) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\autograd\tracer.py in new_box(value, trace, node)
#     117     try:
# --> 118         return box_type_mappings[type(value)](value, trace, node)
#     119     except KeyError:
#
# KeyError: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-75f05c62e6e1> in <module>
#       1 for i in progressbar.progressbar(range(steps), redirect_stdout=True):
# ----> 2     params = optimizer.step(cost_function, params)
#       3     print(' | New parameters:', params)
#       4     print("\n", dev.num_executions)
#       5     f = open(savestring + "paramsQuicksaveIBM.txt", 'a+')
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\optimize\gradient_descent.py in step(self, objective_fn, grad_fn, *args, **kwargs)
#     127         """
#     128
# --> 129         g, _ = self.compute_grad(objective_fn, args, kwargs, grad_fn=grad_fn)
#     130         new_args = self.apply_grad(g, args)
#     131
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\optimize\gradient_descent.py in compute_grad(objective_fn, args, kwargs, grad_fn)
#     156         """
#     157         g = get_gradient(objective_fn) if grad_fn is None else grad_fn
# --> 158         grad = g(*args, **kwargs)
#     159         forward = getattr(g, "forward", None)
#     160
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\_grad.py in __call__(self, *args, **kwargs)
#      99         """Evaluates the gradient function, and saves the function value
#     100         calculated during the forward pass in :attr:`.forward`."""
# --> 101         grad_value, ans = self._get_grad_fn(args)(*args, **kwargs)
#     102         self._forward = ans
#     103         return grad_value
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\autograd\wrap_util.py in nary_f(*args, **kwargs)
#      18             else:
#      19                 x = tuple(args[i] for i in argnum)
# ---> 20             return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#      21         return nary_f
#      22     return nary_operator
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\_grad.py in _grad_with_forward(fun, x)
#     116         difference being that it returns both the gradient *and* the forward pass
#     117         value."""
# --> 118         vjp, ans = _make_vjp(fun, x)
#     119
#     120         if not vspace(ans).size == 1:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\autograd\core.py in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\autograd\tracer.py in trace(start_node, fun, x)
#       8     with trace_stack.new_trace() as t:
#       9         start_box = new_box(x, t, start_node)
# ---> 10         end_box = fun(start_box)
#      11         if isbox(end_box) and end_box._trace == start_box._trace:
#      12             return end_box._value, end_box._node
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\autograd\wrap_util.py in unary_f(x)
#      13                 else:
#      14                     subargs = subvals(args, zip(argnum, x))
# ---> 15                 return fun(*subargs, **kwargs)
#      16             if isinstance(argnum, int):
#      17                 x = args[argnum]
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\vqe\vqe.py in __call__(self, *args, **kwargs)
#     189
#     190     def __call__(self, *args, **kwargs):
# --> 191         return self.cost_fn(*args, **kwargs)
#     192
#     193
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\vqe\vqe.py in cost_fn(*qnode_args, **qnode_kwargs)
#     179                 total = 0
#     180                 for o, c in zip(obs_groupings, coeffs_groupings):
# --> 181                     res = circuit(*qnode_args, obs=o, **qnode_kwargs)
#     182                     total += sum([r * c_ for r, c_ in zip(res, c)])
#     183                 return total
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\qnode.py in __call__(self, *args, **kwargs)
#     665         if self.mutable or self.qtape is None:
#     666             # construct the tape
# --> 667             self.construct(args, kwargs)
#     668
#     669         # If the observable contains a Hamiltonian and the device does not
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\qnode.py in construct(self, args, kwargs)
#     569             # as trainable. This should be removed at some point, forcing users
#     570             # to specify `requires_grad=True` for trainable parameters.
# --> 571             args = [
#     572                 anp.array(a, requires_grad=True) if not hasattr(a, "requires_grad") else a
#     573                 for a in args
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\qnode.py in <listcomp>(.0)
#     570             # to specify `requires_grad=True` for trainable parameters.
#     571             args = [
# --> 572                 anp.array(a, requires_grad=True) if not hasattr(a, "requires_grad") else a
#     573                 for a in args
#     574             ]
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pennylane\numpy\wrapper.py in _wrapped(*args, **kwargs)
#      73
#      74         # evaluate the original object
# ---> 75         res = obj(*args, **kwargs)
#      76
#      77         if isinstance(res, _np.ndarray):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\autograd\numpy\numpy_wrapper.py in array(A, *args, **kwargs)
#      56     t = builtins.type(A)
#      57     if t in (list, tuple):
# ---> 58         return array_from_args(args, kwargs, *map(array, A))
#      59     else:
#      60         return _array_from_scalar_or_array(args, kwargs, A)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\autograd\numpy\numpy_wrapper.py in array(A, *args, **kwargs)
#      56     t = builtins.type(A)
#      57     if t in (list, tuple):
# ---> 58         return array_from_args(args, kwargs, *map(array, A))
#      59     else:
#      60         return _array_from_scalar_or_array(args, kwargs, A)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\autograd\tracer.py in f_wrapped(*args, **kwargs)
#      44             ans = f_wrapped(*argvals, **kwargs)
#      45             node = node_constructor(ans, f_wrapped, argvals, kwargs, argnums, parents)
# ---> 46             return new_box(ans, trace, node)
#      47         else:
#      48             return f_raw(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\autograd\tracer.py in new_box(value, trace, node)
#     118         return box_type_mappings[type(value)](value, trace, node)
#     119     except KeyError:
# --> 120         raise TypeError("Can't differentiate w.r.t. type {}".format(type(value)))
#     121
#     122 box_types = Box.types
#
# TypeError: Can't differentiate w.r.t. type <class 'int'>

# %%
@qml.qnode(dev)
def probability_circuit(gamma, alpha):
    circuit([gamma, alpha])
    return qml.probs(wires=wires)


probs = probability_circuit(params[0], params[1])

# %%
plt.style.use("seaborn")
plt.bar(range(2 ** len(wires)), probs)
plt.savefig(savestring + ".png")
plt.show()

# %%
dev._circuit.draw(output="mpl")

# %%
  (-6.0) [Z2]
+ (-3.0) [Z0]
+ (-1.5) [Z1]
+ (1.0) [Z0 Z1]
+ (2.0) [Z1 Z2]
+ (4.0) [Z0 Z2]

# %%
{(0, 1): 1.0, (0, 2): 4.0, (1, 2): 2.0}

# %% [markdown]
# ## QBSolv

# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import networkx as nx
import plotly.express as px
import seaborn as sns
import random

from dwave_qbsolv import QBSolv

import dimod
import neal
from dwave.system.samplers import DWaveSampler
from dwave.system.composites import EmbeddingComposite
from dwave.system import LeapHybridSampler

# %%
#QBSolve
def on_QBsolve(qubo_dictionary):
    result = QBSolv().sample_qubo(qubo_dictionary)
    return result

# %%
on_QBsolve(qubo_d)
# Out:
# SampleSet(rec.array([([1, 1, 0], -9., 23), ([0, 0, 1], -9., 28)],
#           dtype=[('sample', 'i1', (3,)), ('energy', '<f8'), ('num_occurrences', '<i4')]), Variables([0, 1, 2]), {}, 'BINARY')
